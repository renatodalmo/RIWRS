# %% [markdown]
# ### Linkedin - Empresas em que trabalham os meus contatos

# %%
CSV_FILE = 'D:\\Dropbox\\Pos Big Data\\14-RECUPERAÇÃO DA INFORMAÇÃO NA WEB E EM REDES SOCIAIS\\Basic_LinkedInDataExport_07-14-2018\\Connections.csv'

# %%
from prettytable import PrettyTable
import sys
import nltk
import csv

# %%
# Handle any known abbreviations,CSV_FILE,encoding="utf8"
# strip off common suffixes, etc.

transforms = [(', Inc.', ''), (', Inc', ''), (', LLC', ''), (', LLP', '')]

csvReader = csv.DictReader(open(CSV_FILE,encoding="utf8"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]
companies = [c['Company'].strip() for c in contacts if c['Company'].strip() != '']

for i in range(len(companies)):
    for transform in transforms:
        companies[i] = companies[i].replace(*transform)

ufu = 'Universidade Federal de Uberlândia'      
iftm = 'Instituto Federal de Educação, Ciência e Tecnologia do Triângulo Mineiro'
puc = 'Pontifícia Universidade Católica de Minas Gerais'
zup = 'Zup Innovation'
standardize = [('Federal University of Uberlandia', ufu), 
               ('UFU - Universidade Federal de Uberlândia', ufu), 
               ('Universidade Federal de Uberlândia - UFU', ufu), 
               ('IFTM - Inst. Fed. de Educação, Ciência e Tecnologia do Triângulo Mineiro', iftm),
               ('Federal University of Uberlândia',ufu),
               ('Universidade Federal de Uberlandia',ufu),
               ('Instituto Federal de Minas Gerais',iftm),
               ('Instituto Federal Minas Gerais',iftm),
               ('UFU',ufu),
               ('PUC Minas',puc),
               ('Zup It Innovation',zup),
               ('Zup - Connect & Transform',zup)
              ]
for i in range(len(companies)):
    for standard in standardize:
        companies[i] = companies[i].replace(standard[0],standard[1])

        
        
pt = PrettyTable(['Company', 'Freq'])

pt.align['Company'] = 'l'
fdist = nltk.FreqDist(companies)
[pt.add_row([company, freq]) for (company, freq) in fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +---------------------------------------------------------------+------+
# | Company                                                       | Freq |
# +---------------------------------------------------------------+------+
# | Algar Telecom                                                 |  43  |
# | Algar Tech                                                    |  31  |
# | Zup Innovation                                                |  11  |
# | Softbox - Soluções Inteligentes em TI                         |  11  |
# | Algar Tecnologia                                              |  11  |
# | everis                                                        |  10  |
# | Kyros Tecnologia                                              |  7   |
# | Itaú Unibanco                                                 |  7   |
# | Governa Soluções                                              |  6   |
# | Cedro Technologies                                            |  6   |
# | Autônomo                                                      |  6   |
# | ValeCard                                                      |  5   |
# | Callink Servicos de Call Center                               |  5   |
# | webAula                                                       |  4   |
# | UNIVERSO - Universidade Salgado de Oliveira                   |  4   |
# | TQI +Tecnologia +Qualidade +Inovação                          |  4   |
# | Scopus Soluções em TI                                         |  4   |
# | Sankhya Gestão de Negócios                                    |  4   |
# | Martins                                                       |  4   |
# | ASOEC                                                         |  4   |
# | UNITRI - Centro Universitário do Triângulo                    |  3   |
# | Tribanco                                                      |  3   |
# | Neppo Tecnologia da Informação                                |  3   |
# | Hekima                                                        |  3   |
# | Eletrozema                                                    |  3   |
# | Banco Triangulo S/A                                           |  3   |
# | media-core®                                                   |  2   |
# | Zillion Tecnologia                                            |  2   |
# | Up Brasil                                                     |  2   |
# | Universidade Federal de Uberlândia                            |  2   |
# | Unitri - Centro Universitário do Triângulo                    |  2   |
# | Unitri                                                        |  2   |
# | Unimed Uberlândia                                             |  2   |
# | Sonner Administração Pública                                  |  2   |
# | Softbox - Serviços Inteligentes em TI                         |  2   |
# | SWB SoftWare Brasil, Soluções Integradas                      |  2   |
# | Prefeitura Municipal de Uberlândia                            |  2   |
# | Pontifícia Universidade Católica de Minas Gerais              |  2   |
# | Peixoto Atacado                                               |  2   |
# | MD2 Consultoria                                               |  2   |
# | Itaú                                                          |  2   |
# | Interação Tecnologia                                          |  2   |
# | Inteligência de Negócios                                      |  2   |
# | Inteligencia de Negocios                                      |  2   |
# | Governa Soluções para gestão pública e atendimento ao cidadão |  2   |
# | Funcional - Health Management                                 |  2   |
# | FMC - Financial Management Control                            |  2   |
# | FIA - Fundação Instituto de Administração                     |  2   |
# | CI&T                                                          |  2   |
# +---------------------------------------------------------------+------+

# %% [markdown]
# ### Linkedin - Cargos que ocupam os meus contatos

# %%
import sys
import nltk
import csv
from prettytable import PrettyTable

professor = 'Professor de Ensino Superior'
professor_basico = 'Professor'
analista_ti = 'Analista de Sistemas'
engenheiro_sw = 'Engenheiro de Software'
transforms = [
    ('Sr.', 'Senior'),
    ('Sr', 'Senior'),
    ('Jr.', 'Junior'),
    ('Jr', 'Junior'),
    ('CEO', 'Chief Executive Officer'),
    ('COO', 'Chief Operating Officer'),
    ('CTO', 'Chief Technology Officer'),
    ('CFO', 'Chief Finance Officer'),
    ('VP', 'Vice President'),
    ('Full Professor',professor),
    ('Professor Dedicação Exclusiva',professor),
    ('Professor Adjunto nível A',professor),
    ('Associate Professor',professor),
    ('Full Time Professor',professor),
    ('Professora Assistente',professor),
    ('Professor adjunto',professor),
    ('Professor do Magistério Superior',professor),
    ('Professora Adjunto',professor),
    ('Professora',professor),
    ('Adjunct Professor',professor),
    ('Professor de Ensino Superior',professor),
    ('Docente',professor_basico),
    #('Professor',professor_basico),
    ('Analista de TI',analista_ti),
    ('Systems Analyst',analista_ti),
    ('Analista de Sistemas, Especialista',analista_ti),
    ('Analista de TI - Administradora Siebel',analista_ti),
    ('Senior System Development Analyst C++',analista_ti),
    ('Analista Desenvolvedor de Sistemas',analista_ti),
    ('Analista de sistemas',analista_ti),
    ('Analista de Sistemas Especialista',analista_ti),
    ('System Analyst and Senior Full-Stack Developer',analista_ti),
    ('Analista de TI Pleno',analista_ti),
    ('Information Technology Analyst',analista_ti),
    ('Analista de sistema',analista_ti),
    ('Desenvolvedor e Analista de Sistemas',analista_ti),
    ('Analista Programador',analista_ti),
    ('Analista de Desenvolvimento de Sistemas',analista_ti),
    ('Analista de desenvolvimento de software',analista_ti),
    ('Analista de Tecnologia da Informação',analista_ti),
    ('System Analyst',analista_ti),
    ('Software Engineer',engenheiro_sw),
    ('Software Engineering',engenheiro_sw),
    ('System Software Engineer',engenheiro_sw),
    ('Software engineer',engenheiro_sw),
    ('Senior Software Engineer Team Lead',engenheiro_sw),
    ('Senior C++ Software Engineer',engenheiro_sw),
    ('Engenheiro de software',engenheiro_sw),
    ('Senior Engenheiro de Software',engenheiro_sw),
    ('System Engenheiro de Software',engenheiro_sw),
    ('Software Developer',engenheiro_sw),
    ('Desenvolvedor',engenheiro_sw),
    ('Analista Desenvolvedor',engenheiro_sw),
    ('Analista Engenheiro de Software',engenheiro_sw),
    ('Software Development Engineer',engenheiro_sw),
    ('Senior C++ Engenheiro de Software',engenheiro_sw),
    ('Engenheiro de Software na ZUP',engenheiro_sw),
    ('Staff Engenheiro de Software',engenheiro_sw)
    
    ]

csvReader = csv.DictReader(open(CSV_FILE,encoding="utf8"), delimiter=',', quotechar='"')
contacts = [row for row in csvReader]

# Read in a list of titles and split apart
# any combined titles like "President/CEO"
# Other variations could be handled as well such
# as "President & CEO", "President and CEO", etc.

titles = []
for contact in contacts:
    titles.extend([t.strip() for t in contact['Position'].split('/')
                  if contact['Position'].strip() != ''])

# Replace common/known abbreviations

for i in range(len(titles)):
    for transform in transforms:
        titles[i] = titles[i].replace(*transform)

# Print out a table of titles sorted by frequency

pt = PrettyTable(['Position', 'Freq'])
pt.align['Position'] = 'l'
titles_fdist = nltk.FreqDist(titles)
[pt.add_row([title, freq]) for (title, freq) in titles_fdist.items() if freq > 1]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)

# Print out a table of tokens sorted by frequency

tokens = []
for title in titles:
    tokens.extend([t.strip(',') for t in title.split()])
pt = PrettyTable(['Token', 'Freq'])
pt.align['Token'] =  'l'
tokens_fdist = nltk.FreqDist(tokens)
[pt.add_row([token, freq]) for (token, freq) in tokens_fdist.items() if freq > 1
 and len(token) > 2]
pt = pt.get_string(sortby="Freq", reversesort=True)
print(pt)
# Out:
# +----------------------------------------+------+
# | Position                               | Freq |
# +----------------------------------------+------+
# | Analista de Sistemas                   |  21  |
# | Engenheiro de Software                 |  13  |
# | Professor                              |  9   |
# | Data Scientist                         |  8   |
# | Chief Executive Officer                |  7   |
# | Analista de Negócios                   |  7   |
# | Gerente de projetos                    |  5   |
# | Gerente de Projetos                    |  5   |
# | Owner                                  |  4   |
# | Coordenador                            |  4   |
# | Proprietário                           |  3   |
# | Lead Data Scientist                    |  3   |
# | IT Coordinator                         |  3   |
# | Gerente de TI                          |  3   |
# | Diretor de TI                          |  3   |
# | Diretor                                |  3   |
# | Database Administrator                 |  3   |
# | Analista de Sistemas Pleno             |  3   |
# | Analista de Recursos Humanos           |  3   |
# | Analista de Business Intelligence      |  3   |
# | Analista de BI                         |  3   |
# | Analista                               |  3   |
# | Vice President                         |  2   |
# | System Development Analyst             |  2   |
# | Supervisor                             |  2   |
# | Scrum master                           |  2   |
# | Scrum Master                           |  2   |
# | Professor de Ensino Superior de Inglês |  2   |
# | Professor de Ensino Superior           |  2   |
# | Presidente                             |  2   |
# | Líder de projetos                      |  2   |
# | IT Director                            |  2   |
# | Head of Data Science                   |  2   |
# | Gerente de Projetos de TI              |  2   |
# | Gerente TI                             |  2   |
# | Founder                                |  2   |
# | Financeiro                             |  2   |
# | Engenheiro de Software de software     |  2   |
# | Engenheiro de Software Pleno           |  2   |
# | Diretor Executivo                      |  2   |
# | DBA Oracle                             |  2   |
# | Coordenador de TI                      |  2   |
# | Consultor BI                           |  2   |
# | Co-Founder                             |  2   |
# | Back-end Developer                     |  2   |
# | BI                                     |  2   |
# | Assistente Técnico                     |  2   |
# | Analista financeiro                    |  2   |
# | Analista de negócios                   |  2   |
# | Analista de desenvolvimento            |  2   |
# | Analista de Sistemas Sênior            |  2   |
# | Analista de Serviços Junior            |  2   |
# +----------------------------------------+------+
# +------------------+------+
# | Token            | Freq |
# +------------------+------+
# | Analista         | 128  |
# | Gerente          |  46  |
# | Engenheiro       |  37  |
# | Software         |  36  |
# | Sistemas         |  36  |
# | Data             |  32  |
# | Professor        |  21  |
# | Diretor          |  21  |
# | Consultor        |  21  |
# | Senior           |  20  |
# | Scientist        |  19  |
# | Coordenador      |  18  |
# | Chief            |  17  |
# | Officer          |  16  |
# | Manager          |  15  |
# | Executive        |  15  |
# | Projetos         |  14  |
# | Intelligence     |  14  |
# | Business         |  14  |
# | Sênior           |  13  |
# | Pleno            |  13  |
# | Supervisor       |  12  |
# | Processos        |  11  |
# | Negócios         |  11  |
# | Especialista     |  11  |
# | projetos         |  10  |
# | Técnico          |  10  |
# | Coordenadora     |  10  |
# | Analyst          |  10  |
# | and              |  9   |
# | Analytics        |  9   |
# | negócios         |  8   |
# | Suporte          |  8   |
# | Owner            |  8   |
# | Humanos          |  8   |
# | Director         |  8   |
# | Digital          |  8   |
# | Desenvolvimento  |  8   |
# | Assistente       |  8   |
# | Superior         |  7   |
# | Infraestrutura   |  7   |
# | Ensino           |  7   |
# | Developer        |  7   |
# | Recursos         |  6   |
# | Operações        |  6   |
# | Lead             |  6   |
# | Junior           |  6   |
# | Gestor           |  6   |
# | Consultant       |  6   |
# | Big              |  6   |
# | sênior           |  5   |
# | desenvolvimento  |  5   |
# | Telecom          |  5   |
# | Specialist       |  5   |
# | Product          |  5   |
# | PMO              |  5   |
# | Leader           |  5   |
# | Head             |  5   |
# | Executivo        |  5   |
# | Engineer         |  5   |
# | DBA              |  5   |
# | Co-Founder       |  5   |
# | Administrator    |  5   |
# | vendas           |  4   |
# | suporte          |  4   |
# | software         |  4   |
# | processos        |  4   |
# | dados            |  4   |
# | Vendas           |  4   |
# | Serviços         |  4   |
# | Scrum            |  4   |
# | Sales            |  4   |
# | Marketing        |  4   |
# | Líder            |  4   |
# | Java             |  4   |
# | Gestão           |  4   |
# | Geral            |  4   |
# | Founder          |  4   |
# | Equipe           |  4   |
# | Dados            |  4   |
# | Consultora       |  4   |
# | Comercial        |  4   |
# | Cientista        |  4   |
# | Architect        |  4   |
# | Administrativo   |  4   |
# | ANALISTA         |  4   |
# | tecnologia       |  3   |
# | pleno            |  3   |
# | financeiro       |  3   |
# | Web              |  3   |
# | Vice             |  3   |
# | Tecnologia       |  3   |
# | System           |  3   |
# | Soluções         |  3   |
# | Solution         |  3   |
# | Services         |  3   |
# | Service          |  3   |
# | Science          |  3   |
# | Qlikview         |  3   |
# | Proprietário     |  3   |
# | Project          |  3   |
# | President        |  3   |
# | Partner          |  3   |
# | Oracle           |  3   |
# | Operacional      |  3   |
# | Lider            |  3   |
# | Inovação         |  3   |
# | Financeiro       |  3   |
# | Development      |  3   |
# | Database         |  3   |
# | Coordinator      |  3   |
# | Atendimento      |  3   |
# | área             |  2   |
# | telecomunicações |  2   |
# | qualidade        |  2   |
# | operações        |  2   |
# | master           |  2   |
# | júnior           |  2   |
# | informação       |  2   |
# | freelancer       |  2   |
# | contas           |  2   |
# | VENDAS           |  2   |
# | Transformação    |  2   |
# | Telecomunicações |  2   |
# | Tech             |  2   |
# | Talentos         |  2   |
# | Sócio-Diretor    |  2   |
# | Sócio            |  2   |
# | Support          |  2   |
# | Supervisora      |  2   |
# | Social           |  2   |
# | Seleção          |  2   |
# | Segurança        |  2   |
# | SQL              |  2   |
# | Recrutamento     |  2   |
# | Qualidade        |  2   |
# | QlikView         |  2   |
# | Programador      |  2   |
# | Principal        |  2   |
# | Presidente       |  2   |
# | Planejamento     |  2   |
# | Penal            |  2   |
# | PHP              |  2   |
# | PCP              |  2   |
# | Organizacional   |  2   |
# | Oficial          |  2   |
# | Novos            |  2   |
# | Mobile           |  2   |
# | Mercado          |  2   |
# | Master           |  2   |
# | Inglês           |  2   |
# | Infrastructure   |  2   |
# | Informática      |  2   |
# | Informações      |  2   |
# | Imobiliário      |  2   |
# | Humano           |  2   |
# | Graduação        |  2   |
# | Governança       |  2   |
# | Fundador         |  2   |
# | Financial        |  2   |
# | Filial           |  2   |
# | Estagiária       |  2   |
# | Direito          |  2   |
# | Delivery         |  2   |
# | Contábil         |  2   |
# | Comunicação      |  2   |
# | Chefe            |  2   |
# | Back-end         |  2   |
# | Auxiliar         |  2   |
# | Arte             |  2   |
# | Algar            |  2   |
# | Advisor          |  2   |
# | Advanced         |  2   |
# | .NET             |  2   |
# +------------------+------+

# %% [markdown]
# ### Linkedin - Clusterizando meus contatos por cargos

# %%
# -*- coding: utf-8 -*-

import sys
import csv
from nltk.metrics.distance import masi_distance
from nltk.metrics.distance import jaccard_distance


DISTANCE_THRESHOLD = 0.67
DISTANCE = jaccard_distance

#DISTANCE_THRESHOLD = 0.2
#DISTANCE = masi_distance


def cluster_contacts_by_title(csv_file):
   

    #separators = ['/', 'and', '&', 'de', '-', 'e', ' ']
    separators = ['/', 'and', '&', '-', 'de']

    csvReader = csv.DictReader(open(csv_file,encoding="utf8"), delimiter=',', quotechar='"')
    contacts = [row for row in csvReader]

    # Normalize and/or replace known abbreviations
    # and build up list of common titles

    all_titles = []
    for i in range(len(contacts)):
        if contacts[i]['Position'] == '':
            contacts[i]['Position'] = ['']
            continue
        titles = [contacts[i]['Position']]
        for title in titles:
            for seperator in separators:
                if title.find(seperator) >= 0:
                    if title in titles:
                        titles.remove(title)
                    titles.extend([title.strip() for title in title.split(seperator)
                                   if title.strip() != ''])

        for transform in transforms:
            titles = [title.replace(*transform) for title in titles]
        contacts[i]['Position'] = titles
        all_titles.extend(titles)

    all_titles = list(set(all_titles))

    clusters = {}
    for title1 in all_titles:
        clusters[title1] = []
        for title2 in all_titles:
            if title2 in clusters[title1] or title2 in clusters and title1 \
                in clusters[title2]:
                continue
            distance = DISTANCE(set(title1.split()), set(title2.split()))
            ##print(distance, set(title1.split()), set(title2.split()))
            if distance < DISTANCE_THRESHOLD:
                clusters[title1].append(title2)


    clusters = [clusters[title] for title in clusters if len(clusters[title]) > 1]
    
    # Round up contacts who are in these clusters and group them together

    clustered_contacts = {}
    for cluster in clusters:
        clustered_contacts[tuple(cluster)] = []
        for contact in contacts:
            for title in contact['Position']:
                if title in cluster:
                    clustered_contacts[tuple(cluster)].append('%s %s.'
                                                              % (contact['First Name'], contact['Last Name'][0]))

    return clustered_contacts


if __name__ == '__main__':
    clustered_contacts = cluster_contacts_by_title(CSV_FILE)

    for titles in clustered_contacts:
        common_titles_heading = 'Common Positions: ' + ', '.join(titles)
        
        descriptive_terms = set(titles[0].split())
        for title in titles:
            descriptive_terms.intersection_update(set(title.split()))
        descriptive_terms_heading = 'Descriptive Terms: ' \
                                    + ', '.join(descriptive_terms)
        print(descriptive_terms_heading)
        print('-' * max(len(descriptive_terms_heading), len(common_titles_heading)))
        print('\n'.join(clustered_contacts[titles]))
        print()
# Out:
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------
# Daniel V.
# finzi e.
# Silomar N.
# Carlos Francisco F.
# Vitor M.
# Samuel B.
# Ana Paula. S.
#
# Descriptive Terms: Analista
# ----------------------------------------------------
# Francisco A.
# Daniele Cristina O.
# Ueber Porfírio S.
# Maudy T.
# Paulo Roberto N.
# Meyriele F.
# Marcelo H.
# Daniel L.
# Gihane A.
# Américo S.
# Eberth M.
# Flavio T.
# Fabiano D.
# Flávia R.
# Pedro Henrique F.
# Cristiano M.
# André C.
# Mauro S.
# Raphael I.
# Igor F.
# Claudia N.
# Jimmy S.
# Alan L.
# Ramon Mota da Silva A.
# Rodrigo G.
# Fernando F.
# Patrícia A.
# Juliano S.
# Eurípedes Parreira G.
# Daniel B.
# Warla  L.
# Sérgio A.
# Evandro Luiz M.
# Renato F.
# Wendell C.
# Murilo A.
# Vivaldo R.
# Tiago R.
# Avilander C.
# Thais R.
# Andréia d.
# Rafael B.
# Daniel S.
# Wendel S.
# Gabriela B.
# Rodrigo R.
# Vilso R.
# Hugo M.
# Bruno S.
# Vitor Adolfo A.
# Rodrigo R.
# Pedro Henrique C.
# Alan K.
# Alan L C.
# Walxiney G.
# Aurélio R.
# Arthur D.
# Marques M.
# Bruce S.
# Diego V.
# Luiz Alberto A.
# Andreia V.
# Gleicimara A.
# weberson alex s.
# Daniel B.
# Juliana F.
# Rondinele S.
# Antenor M.
# Luis Otavio M.
# Cleide S.
# Bruno Q.
# Vander G.
# Dione F.
# Vítor V.
# Ellen Diana G.
# Rodrigo G.
# Patrícia S.
# Vitor A.
# Loraine A.
# Welington M.
# Milton F.
# Andreia G.
# Felipe Eduardo S.
# Analice S.
# Leticia A.
# Danilo M.
# Humberto P.
# Daniel M.
# Lorena C.
# Natália R.
# marco m.
# Leoci M.
# Maycon E.
# Samuel Á.
# Lorena M.
# Johnatan G.
# Jackson R.
# Ana Paula. S.
# Elvis R.
# Oberdan M.
# Danilo M.
# Guilherme N.
# Claudio H.
# Diogo J.
# Letícia R.
# Isabela B.
# Ronaldo D.
# Luiz Alberto R.
# Letícia M.
# Alirio P.
#
# Descriptive Terms: TI
# ----------------------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Dinis, A.
# Dinis, A.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Partner
# --------------------------------------------------------------------------
# Emerson R.
# RAFAEL S.
# William N.
#
# Descriptive Terms: Ven
# ---------------------------------------------
# Vivaldo N.
# Vivaldo N.
#
# Descriptive Terms: Analyst
# --------------------------------------------------------------------------
# William S.
# Hugo C.
# Débora J.
#
# Descriptive Terms: Engenheiro
# ----------------------------------------------------------------
# Volnei F.
# Vagner C.
# Clayton T.
# Leonardo A.
# Filipe V.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Árley L.
# Tiago M.
# Tiago M.
# Bruno Garcia d.
# Marcelo S.
# Warla  L.
# Henrique C.
# Gabriela B.
# Josy C.
# Gabriel L.
# Gabriel L.
# Rodrigo O.
# Otávio F.
# Eduardo S.
# Analice S.
# Letícia M.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------------------------------------------
# Árley L.
# Henrique C.
# Henrique C.
# Bruna A.
# Davi C.
#
# Descriptive Terms:
# -------------------------------------------------------------
# Vinicius V.
# Delzilaine A.
# Michael H.
#
# Descriptive Terms: Manager
# ---------------------------------------------------------------------------------------------
# Marcio G.
# Márcio E.
# Jose Maria F.
# Daniel "Dan" C.
# Livia B.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------
# Alberto R.
# Ricardo T.
# Ricardo A.
# Giselle M.
# Giselle M.
# Bruno A.
# Dieslei M.
#
# Descriptive Terms: Administrator
# ---------------------------------------------------------------
# Márcio d.
# Marcio G.
# Rodrigo S.
# Mauro S.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Aldebaran I.
# Sergio S.
# Mário P.
# Alberto R.
# Andreia M.
# Árley L.
# Fabio C.
# Daniel de Sousa  .
# Rui T.
# Tarcisio Abadio d.
# Ricardo A.
# Ricardo A.
# Fabiano C.
# Fabiano C.
# Flavio S.
# José Rogério B.
# Suélen M.
# Vostimar O.
# Germano M.
# Roosevelt O.
# Ana Maria S.
# Wagner P.
# Guilherme V.
# Guilherme V.
# Antônio Carlos O.
# Delzilaine A.
# Henrique Fernandes P.
# Sandro C.
# Sandro C.
# Jony T.
# Débora F.
# Cristiano D.
# Renato M.
# Henrique C.
# Rafael B.
# PEDRO MAURO R.
# Marcelo M.
# Luiz J.
# Rodrigo A.
# Rodrigo A.
# Joaquim Leonardo B.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Lucas M.
# Eduardo C.
# Marcio M.
# Marcio M.
# Gabriel L.
# Diego V.
# Gregonio E.
# Claudiney R.
# Denis L.
# Vanderson (Az) B.
# Antenor M.
# Fabricio M.
# Kriscia M.
# William Z.
# Isabela Cristine C.
# Andre W.
# Arnaldo C.
# Renato S.
# José Otavio A.
# José Otavio A.
# Paula M.
# Danilo M.
# Thiago Campos M.
# Thiago Campos M.
# Luiz Daniel C.
# José Luís Fernandes P.
# TIAGO VINICIUS C.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Pleno
# ------------------------------------------------------------------------------------------------------------
# Daniel L.
# Tiago R.
# Bruno S.
# Dione F.
# Danilo M.
# Humberto P.
# Johnatan G.
#
# Descriptive Terms: Consultor
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Andreia M.
# Leandro S.
# Bruno R.
# Henrique Fernandes P.
# Jobenil Luiz M.
# Arthur M.
# Roberto S.
# Éverton F.
# Vanderson (Az) B.
# Luis J.
# Roberto F.
# clemente dalmo l.
# Francisco Danilo S.
# Flammarion C.
# Maycon E.
# Maycon E.
#
# Descriptive Terms: Lea
# ----------------------------------------------
# Árley L.
# Árley L.
# Josenaldo d.
# Frederico A.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------
# Meyriele F.
# Eduardo M.
# Jimmy S.
# Vagner C.
# Joaquim Leonardo B.
# Fabricio M.
# Rodrigo G.
# Felipe Eduardo S.
# adams f.
# Leoci M.
# Danillo A.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Daniel de Sousa  .
# Flavio T.
# Daniel F.
# Pedro Henrique F.
# André C.
# Raphael I.
# Alan L.
# Juliano S.
# Vivaldo R.
# Avilander C.
# Andréia d.
# Bruno S.
# Alan L C.
# Marques M.
# Rondinele S.
# Vander G.
# Welington M.
# Humberto P.
# Samuel Á.
# Luiz Alberto R.
#
# Descriptive Terms: Scientist, Data
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Vitor O.
# Paulo C.
# André Luiz S.
# Gilberto T.
# Alceu F.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Felipe S.
# Victor G.
# Gustavo P.
# Sandor C.
# Tiago N.
# Filipe C.
# Matheus d.
# Thiago R.
# Ricardo P.
# Jéssika  R.
#
# Descriptive Terms: negócios
# ---------------------------------------------------------------------------------------------------------------------------------
# ALVASON M.
# Paulo Roberto N.
# Meyriele F.
# Fernando F.
# Hugo M.
# Elisangela F.
# Vitor A.
#
# Descriptive Terms: Projetos
# -----------------------------------------------------------
# Árley L.
# Árley L.
# Rui T.
# Fabiano C.
# Sandro C.
# Natália O.
# Jony T.
# Elder A.
# Rafael B.
# Luiz J.
# Gregonio E.
# Izabella E.
# Lorena L.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------
# Américo S.
# Henrique C.
# Murilo A.
# weberson alex s.
# Davi C.
# Marcos Paulo m.
# Luís Santos A.
# Wannisson F.
#
# Descriptive Terms:
# -----------------------------------------
# Jose Antonio F.
# Zaima M.
# Marcelo N.
# Camargos ..
# José Maria M.
#
# Descriptive Terms: Data
# --------------------------------------------------------------------------------------------------------------
# Paulo C.
# Eduardo H.
# Eduardo H.
# Alceu F.
# Tiago M.
# Tiago M.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Henrique C.
# Henrique C.
# Victor G.
# Gustavo P.
# Felipe A.
# Jota J.
# Thiago R.
# Ricardo P.
#
# Descriptive Terms: e, Analista
# ---------------------------------------------------------------------------------------------------------
#  Crênio Roberto S.
#  Crênio Roberto S.
# Natália O.
#
# Descriptive Terms: Consultor
# ----------------------------------------------------------------------------------------------------------------------------------------
# Andreia M.
# Leandro S.
# Bruno R.
# Henrique Fernandes P.
# Jobenil Luiz M.
# Arthur M.
# Roberto S.
# Éverton F.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Francisco Danilo S.
# Flammarion C.
# Maycon E.
# Maycon E.
#
# Descriptive Terms:
# ---------------------------------------------------------------------
# Meyriele F.
# Vitor A.
# Filipe V.
#
# Descriptive Terms: Scrum
# -----------------------------------------------------------
# Alexandre D.
# Paulo S.
# Ariovaldo N.
# Leandro Cassilha K.
#
# Descriptive Terms: Officer, Chief
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Marcio Junior V.
# Eder B.
# Eder B.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Diego D.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: telecomunicações
# ----------------------------------------------------------------
# Pedro Henrique C.
# Oberdan M.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Daniel L.
# Suélen M.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Bruno S.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Eduardo C.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Antenor M.
# Dione F.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Danilo M.
# Thiago Campos M.
# Humberto P.
# Johnatan G.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Atendimento
# -------------------------------------------------
# Rodrigo A.
# Giselle M.
# Giselle M.
#
# Descriptive Terms: Superior, Ensino
# ------------------------------------------------------------------------------------------------------
# Fernando M.
# Karina E.
# Franklin F.
# Larisse D.
# Raissa M.
# Sonia G.
#
# Descriptive Terms: Técnico
# -------------------------------------------------------------------------------------------
# João Alair C.
# Crenilson P.
# Neuton S.
#
# Descriptive Terms: of, Advanced, Analytics
# --------------------------------------------------------------------------------
# Eduardo H.
# Eduardo H.
#
# Descriptive Terms: de
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Daniel F.
# Renato B.
# Willian B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Marcos Fernando B.
# Regiane M.
# Luis Gustavo d.
# Alan F.
# João R.
# Gustavo P.
# Diogo Henrique G.
# Vilso R.
# Rodrigo F.
# Linces M.
# Erick D.
# Fernando Q.
# João Paulo S.
# Cleuto M.
# Rodrigo S.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Cristiano R.
#
# Descriptive Terms: Foun
# -------------------------------
# Rafael G.
# Eder B.
# Eder B.
# Vinícius C.
# Vazhakodan G.
# Marcos Paulo B.
# Filipe F.
# Thiago F.
# Thiago F.
# Matheus G.
#
# Descriptive Terms: Analista
# ---------------------------------------------------------------------------------------------------------------------------
# Francisco A.
# Daniele Cristina O.
# Ueber Porfírio S.
# Maudy T.
# Paulo Roberto N.
# Meyriele F.
# Marcelo H.
# Daniel L.
# Gihane A.
# Thiago Willian A.
# Felipe P.
# Américo S.
# Eberth M.
# Flavio T.
# Juliano M.
# Fabiano D.
# Flávia R.
# Pedro Henrique F.
# Cristiano M.
# André C.
# Mauro S.
# Raphael I.
# Igor F.
# Claudia N.
# Jimmy S.
# Alan L.
# Ramon Mota da Silva A.
# Rodrigo G.
# Fernando F.
# Patrícia A.
# Juliano S.
# Eurípedes Parreira G.
# Daniel B.
# Warla  L.
# Sérgio A.
# Evandro Luiz M.
# Renato F.
# Wendell C.
# Murilo A.
# Vivaldo R.
# Tiago R.
# Avilander C.
# Thais R.
# Andréia d.
# Rafael B.
# Daniel S.
# Wendel S.
# Gabriela B.
# Rodrigo R.
# Vilso R.
# Hugo M.
# Bruno S.
# Vitor Adolfo A.
# Rodrigo R.
# Pedro Henrique C.
# Alan K.
# Alan L C.
# Walxiney G.
# Aurélio R.
# Arthur D.
# Marques M.
# Bruce S.
# Diego V.
# Vagner A.
# Luiz Alberto A.
# Andreia V.
# Gleicimara A.
# weberson alex s.
# Daniel B.
# Juliana F.
# Rondinele S.
# Antenor M.
# Luis Otavio M.
# Cleide S.
# Bruno Q.
# Vander G.
# Dione F.
# Vítor V.
# Ellen Diana G.
# Rodrigo G.
# Otávio F.
# Vitor A.
# Loraine A.
# Welington M.
# Milton F.
# Andreia G.
# Felipe Eduardo S.
# Analice S.
# Leticia A.
# Danilo M.
# Humberto P.
# Daniel M.
# Lorena C.
# Natália R.
# marco m.
# Leoci M.
# Maycon E.
# Samuel Á.
# Lorena M.
# Johnatan G.
# Jackson R.
# Ana Paula. S.
# Elvis R.
# Oberdan M.
# Danilo M.
# Guilherme N.
# Marcelo R.
# Claudio H.
# Diogo J.
# Letícia R.
# Isabela B.
# Ronaldo D.
# Osvaldo A.
# Luiz Alberto R.
# Letícia M.
# Alirio P.
#
# Descriptive Terms: em, Especialista
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Eduardo A.
# Bruno Garcia d.
# Maiko R.
# Aniceto P.
# Elisangela F.
# Rodrigo A.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------
# Ricardo T.
# Giselle M.
# Giselle M.
# Éverton F.
# Bruno A.
# Dieslei M.
#
# Descriptive Terms: of, Head
# -------------------------------------------------------
# Luciano M.
# Luciano M.
# Luciano M.
# Luciano M.
# Guilherme B.
#
# Descriptive Terms: Analyst
# -----------------------------------------------------
# William S.
# Hugo C.
#
# Descriptive Terms:
# -----------------------------------------------------------------------------------
# Ueber Porfírio S.
# Volnei F.
# Daniel L.
# Suélen M.
# Suélen M.
# Bruno S.
# Aniceto P.
# Dione F.
# Humberto P.
# Johnatan G.
#
# Descriptive Terms: Business
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Tiago M.
# Tiago M.
# Silomar N.
# Bruno Garcia d.
# Marcelo S.
# Warla  L.
# Gabriela B.
# Josy C.
# Gabriel L.
# Rodrigo O.
# Otávio F.
# Eduardo S.
# Analice S.
# Letícia M.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------
# Carlos Maurício F.
# Lafaete R.
# Diogo Henrique M.
# Felipe M.
# Paulo S.
# Daniel V.
# finzi e.
# Carlos Francisco F.
# Jose Maria F.
# Vitor M.
# Samuel B.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------
# Giselle M.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Thaís M.
# Antenor M.
# Guilherme M.
# Milton F.
# Daniel M.
#
# Descriptive Terms: Senior, Analyst
# -----------------------------------------------------------------------------------------------------------
# Weder C.
# Leandro B.
# Alessandra S.
#
# Descriptive Terms: Developer
# --------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Rodrigo S.
# Marcelo L.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------
# Meyriele F.
# Cristiano M.
# Jimmy S.
# Thais R.
# Fabricio M.
# Vítor V.
# Ellen Diana G.
# Wenceslau N.
# Felipe Eduardo S.
#
# Descriptive Terms: Manager
# ------------------------------------------------------------------------------------------------------------
# Caio M.
# Daniel "Dan" C.
# Cristiane V.
# Vitor C.
#
# Descriptive Terms: Manager, Sales
# --------------------------------------------------------------------------
# Marcio G.
# Marcos L.
# Antonio P.
#
# Descriptive Terms: de, Professor, Ensino, Superior
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Paula O.
# Fernando M.
# Karina E.
# Larisse D.
# Raissa M.
# Sonia G.
#
# Descriptive Terms:
# -------------------------------------------------------------------------------------------------------------------------
# Carlos Maurício F.
# Lafaete R.
# Diogo Henrique M.
# Felipe M.
# Paulo S.
# Daniel V.
# Carlos Francisco F.
# Jose Maria F.
# Samuel B.
#
# Descriptive Terms: Scrum
# ---------------------------------------------
# Paulo S.
# Ariovaldo N.
# Leandro Cassilha K.
#
# Descriptive Terms: de, Software
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Regiane M.
# Alan F.
# João R.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Linces M.
# Erick D.
# Fernando Q.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Felipe Amâncio D.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: nt
# -----------------------------------
# Zaima M.
# Marcelo N.
# Marco Antonio S.
#
# Descriptive Terms: Business
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Tiago M.
# Tiago M.
# Silomar N.
# Bruno Garcia d.
# Warla  L.
# Gabriela B.
# Josy C.
# Gabriel L.
# Rodrigo O.
# Otávio F.
# Eduardo S.
# Analice S.
# Letícia M.
#
# Descriptive Terms:
# ------------------------------------------------------
# Marcio Junior V.
# Jobenil Luiz M.
# Guilherme C.
# Leonardo V.
# Luis Otavio M.
# marco m.
# Andressa F.
# Andressa F.
# Andressa F.
#
# Descriptive Terms: Técnico
# -------------------------------------------------------------------------------------
# Agnaldo J.
# Neirivon E.
# Daniel O.
# Edson Nere A.
# João Alair C.
# Sergio dos Santos M.
# Crenilson P.
#
# Descriptive Terms: Supervisor
# ----------------------------------------------------
# Luiz Flávio M.
# Juvenil R.
# Rodrigo A.
# Djone machado M.
# André G.
# Isabela Cristine C.
# Renato S.
# Emerson P.
# Elias T.
# Tatiane M.
#
# Descriptive Terms: Gerente
# -------------------------------------------------------------------------------------------------------
# Aldebaran I.
# Sergio S.
# Mário P.
# Alberto R.
# Árley L.
# Daniel de Sousa  .
# Rui T.
# Tarcisio Abadio d.
# Ricardo A.
# Fabiano C.
# Flavio S.
# Vostimar O.
# Roosevelt O.
# Ana Maria S.
# Guilherme V.
# Antônio Carlos O.
# Delzilaine A.
# Sandro C.
# Débora F.
# Cristiano D.
# Renato M.
# Henrique C.
# Rafael B.
# PEDRO MAURO R.
# Marcelo M.
# Luiz J.
# Rodrigo A.
# Joaquim Leonardo B.
# Lucas M.
# Gabriel L.
# Gregonio E.
# Fabricio M.
# Kriscia M.
# William Z.
# Andre W.
# Arnaldo C.
# José Otavio A.
# Paula M.
# Thiago Campos M.
# Luiz Daniel C.
# José Luís Fernandes P.
# TIAGO VINICIUS C.
#
# Descriptive Terms: Analista
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Francisco A.
# Daniele Cristina O.
# Ueber Porfírio S.
# Maudy T.
# Paulo Roberto N.
# Meyriele F.
# Marcelo H.
# Daniel L.
# Gihane A.
# Thiago Willian A.
# Felipe P.
# Américo S.
# Eberth M.
# Flavio T.
# Fabiano D.
# Flávia R.
# Pedro Henrique F.
# Willian B.
# Cristiano M.
# André C.
# Mauro S.
# Raphael I.
# Igor F.
# Claudia N.
# Jimmy S.
# Alan L.
# Ramon Mota da Silva A.
# Rodrigo G.
# Fernando F.
# Patrícia A.
# Juliano S.
# Eurípedes Parreira G.
# Daniel B.
# Warla  L.
# Sérgio A.
# Evandro Luiz M.
# Renato F.
# Wendell C.
# Luis Gustavo d.
# Murilo A.
# Vivaldo R.
# Tiago R.
# Avilander C.
# Thais R.
# Andréia d.
# Rafael B.
# Daniel S.
# Wendel S.
# Gabriela B.
# Diogo Henrique G.
# Rodrigo R.
# Vilso R.
# Hugo M.
# Bruno S.
# Vitor Adolfo A.
# Rodrigo R.
# Pedro Henrique C.
# Alan K.
# Alan L C.
# Walxiney G.
# Aurélio R.
# Arthur D.
# Marques M.
# Bruce S.
# Diego V.
# Vagner A.
# Luiz Alberto A.
# Andreia V.
# Gleicimara A.
# weberson alex s.
# Daniel B.
# Juliana F.
# Rondinele S.
# Antenor M.
# Luis Otavio M.
# Cleide S.
# Bruno Q.
# Vander G.
# Dione F.
# Vítor V.
# Ellen Diana G.
# Rodrigo G.
# Otávio F.
# Vitor A.
# Loraine A.
# Welington M.
# Milton F.
# Andreia G.
# Felipe Eduardo S.
# Analice S.
# Leticia A.
# Danilo M.
# Humberto P.
# Daniel M.
# Lorena C.
# Natália R.
# marco m.
# Renato M.
# Leoci M.
# Maycon E.
# Maycon E.
# Samuel Á.
# Lorena M.
# Johnatan G.
# Jackson R.
# Ana Paula. S.
# Elvis R.
# Oberdan M.
# Danilo M.
# Guilherme N.
# Marcelo R.
# Claudio H.
# Diogo J.
# Letícia R.
# Isabela B.
# Ronaldo D.
# Osvaldo A.
# Luiz Alberto R.
# Letícia M.
# Cristiano R.
# Alirio P.
#
# Descriptive Terms: Operações
# ----------------------------------------------------------------------------------
# Mário P.
# Flavio S.
# Luís Santos A.
#
# Descriptive Terms: Scientist, Data
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Vitor O.
# Paulo C.
# André Luiz S.
# Gilberto T.
# Alceu F.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Victor G.
# Gustavo P.
# Sandor C.
# Tiago N.
# Filipe C.
# Matheus d.
# Thiago R.
# Ricardo P.
# Jéssika  R.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------
# Antônio Carlos O.
# Murilo A.
# weberson alex s.
# Marcos Paulo m.
# Wannisson F.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------
# Cláudia P.
#  Crênio Roberto S.
#  Crênio Roberto S.
# Renato R.
# Cristiane G.
# Vinicius M.
# Clemerson P.
# Bruna S.
# Nelson A.
# Arianna A.
# Enzo D.
#
# Descriptive Terms: Programador
# ----------------------------------------------------------------
# Giliard J.
# Eduardo V.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Silomar N.
# Bruno Garcia d.
# Warla  L.
# Josy C.
# Rodrigo O.
# Eduardo S.
# Roberto S.
#
# Descriptive Terms:
# -------------------------------------------------------------
# Luciano M.
# Marcos R.
# José Henrique B.
# Eder B.
# B2B V.
# Vinícius C.
# Assis M.
# Leonardo C.
# Aluisio Silva J.
# Marcos Paulo B.
# Pablo Henrique S.
# Pablo Henrique S.
# Tania M.
# Filipe F.
# Thiago F.
# Matheus G.
# Terry  H.
#
# Descriptive Terms: Equipe
# -------------------------------------------------------------
# Tarcisio Abadio d.
# Eduardo E.
# Giselle M.
# Giselle M.
# Erick O.
# Erick O.
#
# Descriptive Terms: Officer, Chief
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Marcio Junior V.
# Eder B.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Diego D.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: BI, Analytics
# --------------------------------------------------------------------------------------------
# Fábio M.
# Leandro H.
# Willians B.
#
# Descriptive Terms: Officer, Chief
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Diego D.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: Operações
# ---------------------------------------------------------
# Henrique C.
# Davi C.
# Luís Santos A.
#
# Descriptive Terms: nador
# ------------------------------------------------
# Jefferson d.
# Fábio C.
# Germano M.
# Wagner P.
# Daniel F.
# Daniel F.
# Hebert A.
# Anderson R.
# Vitor A.
# Guilherme M.
# Fabrício N.
# Amilker C.
# Carla Fernanda F.
# Raphael M.
# Giovani S.
# Túlio Kennedy O.
# Roberta B.
#
# Descriptive Terms:
# --------------------------------------------------------------------------
# Aldebaran I.
# Lillian T.
# Ricardo M.
# Avilander C.
# Bruno Q.
# TIAGO VINICIUS C.
#
# Descriptive Terms: ANALISTA, DE
# ---------------------------------------------------------------------------------------------------
# Rodrigo Rocha R.
# Michele V.
# André Luis G.
#
# Descriptive Terms: Engineer
# ------------------------------------------------
# Raphael H.
# Thiago B.
#
# Descriptive Terms: Sócio
# --------------------------------------------------------------------
# José Luiz O.
# Marcelo S.
# Daiton J.
# Hermes d.
#
# Descriptive Terms: de
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Marcos Fernando B.
# Regiane M.
# Alan F.
# João R.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Erick D.
# Fernando Q.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Felipe Amâncio D.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: Professor
# ---------------------------------------------------------------
# Adams Z.
# Umberto M.
# Rayssa K.
# Pedro A.
# Carlos Henrique P.
# Fábio F.
# Arthur M.
# Tony Alexandre M.
# Carlos Eduardo C.
# Claudiney D.
# Franklin F.
# Carlos Alberto A.
# Igor M.
# José Luiz de Moura F.
# Kevin M.
#
# Descriptive Terms: IT
# --------------------------------------------------------------------------------------------------------------------------------------
# Carlos Maurício F.
# Flamaryon B.
# Lafaete R.
# Diogo Henrique M.
# Felipe M.
# Paulo S.
# Elmiro Cesar B.
# Jose Maria F.
# Helder R.
#
# Descriptive Terms:
# ---------------------------------------------------------
# Marcelo M.
# Rodrigo R.
# Amilker C.
# Jackson R.
#
# Descriptive Terms: projetos
# -------------------------------------------
# Fabiana P.
# Vostimar O.
# Roosevelt O.
# Débora F.
# Fabricio M.
# Paula M.
# Thiago Campos M.
# Chrystian G.
# Luiz Daniel C.
#
# Descriptive Terms: do, Sul
# ----------------------------------
# Antonio Cesar R.
# Antonio Cesar R.
#
# Descriptive Terms: Fundador
# --------------------------------------------
# José Henrique B.
# Rafael P.
# Hermes d.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------
# Wendel S.
# Pedro Henrique C.
# Lucas M.
# Andreia G.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------
# Daniel de Sousa  .
# Daniel L.
# Flavio T.
# Daniel F.
# Pedro Henrique F.
# Alan L.
# Vivaldo R.
# Avilander C.
# Andréia d.
# Bruno S.
# Alan L C.
# Marques M.
# Humberto P.
# Samuel Á.
# Johnatan G.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno Garcia d.
# Maiko R.
# Hugo M.
# Rodrigo O.
# Aniceto P.
# Elisangela F.
# Roberto S.
# Rodrigo A.
#
# Descriptive Terms: Scientist, Data
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Paulo C.
# André Luiz S.
# Gilberto T.
# Alceu F.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Victor G.
# Gustavo P.
# Sandor C.
# Tiago N.
# Filipe C.
# Matheus d.
# Thiago R.
# Ricardo P.
# Jéssika  R.
#
# Descriptive Terms: Manager, Product
# ---------------------------------------------------------------------------
# Vinícius C.
# Vinícius C.
# Vinícius C.
# Vinícius C.
# Livia B.
# Helder R.
#
# Descriptive Terms: Operações
# -----------------------------------------------------------------------
# Henrique C.
# Davi C.
# Davi C.
#
# Descriptive Terms: Humanos
# ----------------------------------------------------
# Cristiano D.
# Patrícia M.
# Andreia V.
# Juliana F.
# Débora R.
# Kriscia M.
# Arianna A.
# Lorena C.
#
# Descriptive Terms: Informação, Tecnologia, da
# -------------------------------------------------------------------------------
# Eberth M.
# Neirivon E.
#
# Descriptive Terms: Scientist, Data
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Paulo C.
# Gilberto T.
# Alceu F.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Victor G.
# Gustavo P.
# Sandor C.
# Tiago N.
# Filipe C.
# Matheus d.
# Thiago R.
# Ricardo P.
# Jéssika  R.
#
# Descriptive Terms: Developer
# -----------------------------------------------------------------------------------
# Marcos L.
# Rodrigo S.
# Euclides S.
# Marco G.
# Lucas G.
#
# Descriptive Terms: Especialista
# --------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno Garcia d.
# Maiko R.
# Rodrigo O.
# Aniceto P.
# Roberto S.
# Rodrigo A.
#
# Descriptive Terms: Consultor
# ---------------------------------------------------------------------------------------------------------------------
# Andreia M.
# Leandro S.
# Bruno R.
# Jobenil Luiz M.
# Arthur M.
# Roberto S.
# Éverton F.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Francisco Danilo S.
# Flammarion C.
# Maycon E.
# Maycon E.
#
# Descriptive Terms: Assistente
# ------------------------------------------------
# Renato R.
# Cristiane G.
# Vinicius M.
# Clemerson P.
# Bruna S.
# Nelson A.
# Arianna A.
#
# Descriptive Terms: Desenvolvimento
# -----------------------------------------------------------------------------------------
# Aldebaran I.
# Avilander C.
# Arthur D.
# Arthur D.
# Bruno Q.
# TIAGO VINICIUS C.
#
# Descriptive Terms:
# --------------------------------------------------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Suélen M.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Evandro Luiz M.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Walxiney G.
# Eduardo C.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Antenor M.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Officer, Chief
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Diego D.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: Consultora
# ----------------------------------------------------------------
# Bruna A.
# Bruna A.
# Kátia L.
# Tatiane O.
#
# Descriptive Terms: Professor
# ------------------------------------------
# Adams Z.
# Umberto M.
# Rayssa K.
# Pedro A.
# Carlos Henrique P.
# Fábio F.
# Tony Alexandre M.
# Carlos Eduardo C.
# Claudiney D.
# Franklin F.
# Carlos Alberto A.
# Igor M.
# José Luiz de Moura F.
# Kevin M.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------
# Cristobal U.
# Andreia M.
# Leandro S.
# Bruno R.
# Jobenil Luiz M.
# Arthur M.
# Roberto S.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Francisco Danilo S.
# Flammarion C.
# Maycon E.
# Maycon E.
# Ana Paula. S.
#
# Descriptive Terms: em, TI
# --------------------------------------------------------------
# Flavio S.
# Hugo M.
#
# Descriptive Terms: nador
# -----------------------------------------
# Jefferson d.
# Daniel F.
# Daniel F.
#
# Descriptive Terms: Data
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Paulo C.
# Gilberto T.
# Alceu F.
# Tiago M.
# Tiago M.
# Ana Carolina L.
# Rodrigo M.
# Clebson S.
# Henrique C.
# Henrique C.
# Victor G.
# Gustavo P.
# Sandor C.
# Filipe C.
# Matheus d.
# Thiago R.
# Ricardo P.
# Jéssika  R.
#
# Descriptive Terms: de, Software
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Regiane M.
# Alan F.
# João R.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Felipe Amâncio D.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: Business
# ------------------------------------------------------------------------------------------------------------------------------------------
# Silomar N.
# Bruno Garcia d.
# Warla  L.
# Eduardo S.
#
# Descriptive Terms: Marketing, Digital
# -------------------------------------------------------------------------------------------
# Tiago O.
# Ana Paula. S.
#
# Descriptive Terms: Administrativo
# -----------------------------------------------------------
# Cláudia P.
#  Crênio Roberto S.
#  Crênio Roberto S.
#
# Descriptive Terms: de, Software
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Renato B.
# Arthur C.
# Rodrigo G.
# Erik U.
# Regiane M.
# Alan F.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Felipe Amâncio D.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: Officer, Chief
# -----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
#
# Descriptive Terms:
# ----------------------------------------------------------------------
# Lilian M.
# Marcelo V.
# weberson alex s.
# Marcos Paulo m.
# Wannisson F.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------------------
# Bruno Garcia d.
# Aniceto P.
# Eduardo S.
# Rodrigo A.
#
# Descriptive Terms: Software
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Daniel F.
# Delzilaine A.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Regiane M.
# Alan F.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: TI
# ------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Hugo M.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Suporte
# -----------------------------------------------
# Giselle M.
# Giselle M.
# Giselle M.
# Milton F.
# Claudio H.
#
# Descriptive Terms: de, Software
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Regiane M.
# Alan F.
# Guilherme C.
# Gustavo P.
# Vilso R.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------
# Marcelo H.
# Daniel L.
# Thiago Willian A.
# Bruno R.
# Hebert A.
# Patrícia A.
# Henrique C.
# Rafael B.
# Bruna A.
# Roberto S.
# Francisco Danilo S.
# Johnatan G.
# Osvaldo A.
#
# Descriptive Terms: r
# ------------------------------
# Luciano M.
# Luciano M.
# Antônio C.
# Rafael G.
# Árley L.
# Árley L.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Vinícius C.
# Vinícius C.
# Fabiana P.
# Josenaldo d.
# Vazhakodan G.
# Marcos Paulo B.
# Frederico A.
# Eduardo E.
# Luismar C.
# Filipe F.
# Filipe F.
# Thiago F.
# Thiago F.
# Thiago F.
# Thiago F.
# Lorena L.
# Erick O.
# Matheus G.
# Matheus G.
# Chrystian G.
# Jéssika  R.
#
# Descriptive Terms: Geral
# -----------------------------------------------------------------
# Uirá R.
# Randal C.
# Pedro A.
# Thais C.
#
# Descriptive Terms: Técnico
# ---------------------------------------------------------------------
# Agnaldo J.
# Renato R.
# Daniel O.
# Clemerson P.
# Edson Nere A.
# Sergio dos Santos M.
# Crenilson P.
# Crenilson P.
#
# Descriptive Terms: e, Custo, Analista
# ----------------------------------------------------------------------------
#  Crênio Roberto S.
#  Crênio Roberto S.
#
# Descriptive Terms: Developer
# -----------------------------------------------
# Euclides S.
# Marco G.
# Lucas G.
#
# Descriptive Terms: Senior, Analyst
# ---------------------------------------------------------------------
# Leandro B.
# Alessandra S.
#
# Descriptive Terms: de, Software
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Renato B.
# Arthur C.
# Rodrigo G.
# Rodrigo G.
# Erik U.
# Alan F.
# Gustavo P.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Cleuto M.
# Rodrigo S.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
#
# Descriptive Terms: e, Processos
# --------------------------------------------------------------
# Maiko R.
# Luciene C.
#
# Descriptive Terms: Vendas
# ---------------------------------------
# Renato M.
# Rosy M.
# Fabrício N.
#  Hingrid Therèse R.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------------------------------------------------------------------
# Daniel L.
# Ana Maria S.
# Fabiano D.
# Juliano S.
# Sérgio A.
# Maiko R.
# Rondinele S.
# Mayra S.
# Welington M.
# Túlio Kennedy O.
#
# Descriptive Terms: DW
# ----------------------------------
# Bruno R.
# Bruna A.
# Bruna A.
#
# Descriptive Terms: senvolvimento
# -----------------------------------------------------
# Ramon Mota da Silva A.
# Lucas C.
# Rodrigo R.
# Vitor A.
# Rodrigo G.
# Felipe Eduardo S.
# Leoci M.
#
# Descriptive Terms: Engenheiro, de, Software
# -------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Renato B.
# Arthur C.
# Rodrigo G.
# Erik U.
# Alan F.
# Guilherme C.
# Gustavo P.
# Rodrigo F.
# Erick D.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: Gerente
# -----------------------------------------------------------------------------------------------------------------------------------
# Aldebaran I.
# Sergio S.
# Mário P.
# Alberto R.
# Árley L.
# Árley L.
# Daniel de Sousa  .
# Rui T.
# Tarcisio Abadio d.
# Ricardo A.
# Fabiano C.
# Flavio S.
# Vostimar O.
# Roosevelt O.
# Ana Maria S.
# Guilherme V.
# Antônio Carlos O.
# Delzilaine A.
# Sandro C.
# Débora F.
# Elder A.
# Cristiano D.
# Renato M.
# Henrique C.
# Rafael B.
# PEDRO MAURO R.
# Marcelo M.
# Luiz J.
# Rodrigo A.
# Joaquim Leonardo B.
# Lucas M.
# Gabriel L.
# Gregonio E.
# Fabricio M.
# Kriscia M.
# William Z.
# Andre W.
# Arnaldo C.
# José Otavio A.
# Paula M.
# Thiago Campos M.
# Luiz Daniel C.
# TIAGO VINICIUS C.
#
# Descriptive Terms: Infraestrutura
# ------------------------------------------------------------------------
# Francisco A.
# Thaís M.
# Antenor M.
# Guilherme M.
#
# Descriptive Terms: Engenheiro, de, Software
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Renato B.
# Arthur C.
# Rodrigo G.
# Erik U.
# Alan F.
# Guilherme C.
# Gustavo P.
# Rodrigo F.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Rogério G.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: ANALISTA, DE
# -------------------------------------------------------------------------
# Rodrigo Rocha R.
# André Luis G.
#
# Descriptive Terms: Scientist, Data
# -----------------------------------------------------------------------------------------------------------------
# Gilberto T.
# Sandor C.
# Filipe C.
# Matheus d.
# Jéssika  R.
#
# Descriptive Terms: II
# ------------------------------------------
# Evandro Luiz M.
# Walxiney G.
#
# Descriptive Terms: Processos
# ---------------------------------------------------------
# Daniel L.
# Ana Maria S.
# Sérgio A.
# Maiko R.
# Mayra S.
# Túlio Kennedy O.
#
# Descriptive Terms: sistemas
# -------------------------------------------------------------
# Cristiano M.
# Thais R.
# Vítor V.
# Ellen Diana G.
# Wenceslau N.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------
# Andreia M.
# Marcelo H.
# Thiago Willian A.
# Leandro S.
# Bruno R.
# Bruno R.
# Hebert A.
# Patrícia A.
# Jobenil Luiz M.
# Arthur M.
# Henrique C.
# Rafael B.
# Bruna A.
# Roberto S.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Francisco Danilo S.
# Flammarion C.
# Osvaldo A.
#
# Descriptive Terms: Officer, Chief
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Joctã R.
# Daiton J.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: Data
# ----------------------------------------------------------
# Tiago M.
# Tiago M.
# Henrique C.
# Henrique C.
#
# Descriptive Terms:
# ----------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo H.
# Thiago Willian A.
# Thiago Willian A.
# Felipe P.
# Bruno R.
# Hebert A.
# Patrícia A.
# Henrique C.
# Rafael B.
# Bruna A.
# Vagner A.
# Otávio F.
# Marcelo R.
# Emmanuel d.
# Osvaldo A.
#
# Descriptive Terms: Officer, Chief
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------
# Antônio C.
# Andre M.
# Marcos R.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Joctã R.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: e, Humano, Desenvolvimento, Organizacional
# -----------------------------------------------------------------------------------------------------------------
# Luciana G.
# Fernanda F.
#
# Descriptive Terms: Gerente
# --------------------------------------------------------------------------
# Alberto R.
# Ricardo A.
# Lucas M.
#
# Descriptive Terms: Financeiro
# -----------------------------------------------
# Zenildo J.
# Ricardo T.
# Frederico G.
#
# Descriptive Terms: Processos
# ----------------------------------------
# Ana Maria S.
# Sérgio A.
# Maiko R.
# Mayra S.
# Túlio Kennedy O.
#
# Descriptive Terms: Sistemas
# -------------------------------------------------------------
# Daniel de Sousa  .
# Flavio T.
# Daniel F.
# Pedro Henrique F.
# Willian B.
# Alan L.
# Luis Gustavo d.
# Vivaldo R.
# Avilander C.
# Andréia d.
# Diogo Henrique G.
# Alan L C.
# Marques M.
# Samuel Á.
# Cristiano R.
#
# Descriptive Terms: Analytics
# ---------------------------------------------
# Henrique C.
# Henrique C.
# Joeudes A.
# Gabriel L.
# Gabriel L.
# Guilherme B.
#
# Descriptive Terms: Manager
# ------------------------------------------------------------------------------------------------------------------------------------------
# Flamaryon B.
# Caio M.
# Jose Maria F.
# Daniel "Dan" C.
# Helder R.
# Cristiane V.
#
# Descriptive Terms:
# -------------------------------------------------------------
# Benedito Reynaldo A.
# Marcelo H.
# Thiago Willian A.
# Bruno R.
# Hebert A.
# Patrícia A.
# Rafael B.
# Bruna A.
# Rodrigo O.
# Roberto S.
#
# Descriptive Terms: Advisor, the, to
# ---------------------------------------------------------------------------------
# Antonio P.
# Antonio P.
#
# Descriptive Terms: Diretor, Rio, Filial
# ----------------------------------------------------------------
# Antonio Cesar R.
# Antonio Cesar R.
#
# Descriptive Terms: IT
# --------------------------------------------
# Lafaete R.
# Felipe M.
# Paulo S.
# Jose Maria F.
#
# Descriptive Terms: Services, Director
# ----------------------------------------------------------------
# Carlos Maurício F.
# Diogo Henrique M.
#
# Descriptive Terms: Digital
# ----------------------------------------------------
# Cristobal U.
# Ana Paula. S.
#
# Descriptive Terms: sênior
# ------------------------------------------------------------------------
# Meyriele F.
# Fabricio M.
# Felipe Eduardo S.
#
# Descriptive Terms: sênior
# --------------------------------------------------
# Meyriele F.
# Fabricio M.
#
# Descriptive Terms: Engenheiro
# -----------------------------------------------------------------------
# Volnei F.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Vagner C.
# Arthur C.
# Erik U.
# Gustavo P.
# Rodrigo F.
# Leonardo A.
# João Paulo S.
# Cleuto M.
# Rodrigo S.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Filipe V.
#
# Descriptive Terms: IT, Services
# ------------------------------------------------------------
# Carlos Maurício F.
# Elmiro Cesar B.
#
# Descriptive Terms: DE
# -----------------------------------------------------------------------------------------------------
# Marcos A.
# ROMES V.
# André Luis G.
#
# Descriptive Terms: Suporte
# ------------------------------------------
# Giselle M.
# Giselle M.
# Giselle M.
# Romano A.
# Milton F.
#
# Descriptive Terms: Scientist, Data
# ------------------------------------------------------------------------------------------
# Gilberto T.
# Sandor C.
# Filipe C.
# Jéssika  R.
#
# Descriptive Terms: Infraestrutura
# -------------------------------------------------------------------------------------
# Vitor Adolfo A.
# Luiz Alberto A.
# Thaís M.
# Antenor M.
# Guilherme M.
#
# Descriptive Terms: Analista, de
# --------------------------------------------------------------------------------------------------------------------------
# Willian B.
# Marcos Fernando B.
# Luis Gustavo d.
# Diogo Henrique G.
# Maycon E.
# Mairany C.
# Cristiano R.
#
# Descriptive Terms: de, Professor, Ensino, Superior
# ----------------------------------------------------------------------------------------------------------------------------
# Paula O.
# Fernando M.
# Karina E.
# Raissa M.
# Sonia G.
#
# Descriptive Terms: Suporte
# ---------------------------------------------------------------------------------------------
# Daniel B.
# Giselle M.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Milton F.
# Pedro C.
#
# Descriptive Terms: TI
# ------------------------------------------------------------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Suélen M.
# Suélen M.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Eduardo C.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Sênior
# ---------------------------------------------------------
# Juliano S.
# Welington M.
#
# Descriptive Terms: Scientist, Data
# ---------------------------------------------------------------------
# Filipe C.
# Jéssika  R.
#
# Descriptive Terms: Negócios
# ------------------------------------------------------------------------------------------
# Aldebaran I.
# Gihane A.
# Mauro S.
# Aurélio R.
# Bruce S.
# Rodrigo C.
# Aniceto P.
# Tatiane O.
# Leticia A.
# Natália R.
# Maycon E.
# Maycon E.
#
# Descriptive Terms: Executivo
# -------------------------------------------------------------
# Robson X.
# Daniel A.
# Silvio Cesar M.
# Renato M.
#
# Descriptive Terms: sistemas
# ---------------------------------------------------
# Cristiano M.
# Vítor V.
#
# Descriptive Terms: Software
# ----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Murilo C.
# Jésus L.
# Juliano D.
# Eduardo M.
# Delzilaine A.
# Renato B.
# Arthur C.
# Rodrigo G.
# Erik U.
# Alan F.
# Guilherme C.
# Gustavo P.
# Rodrigo F.
# João Paulo S.
# Vinícius L.
# Cleuto M.
# Rodrigo S.
# Rogério R.
# Michel R.
# adams f.
# Erick O.
# Erick O.
# Tiago P.
# Danillo A.
# Welder N.
#
# Descriptive Terms: Co
# -----------------------------
# Luciano M.
# José Henrique B.
# Eder B.
# Vinícius C.
# Marcos Paulo B.
# Pablo Henrique S.
# Filipe F.
# Thiago F.
# Matheus G.
#
# Descriptive Terms: Consultor
# --------------------------------------------------------------------------------------
# Andreia M.
# Jobenil Luiz M.
# Arthur M.
# Marcio M.
# Marcio M.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Flammarion C.
#
# Descriptive Terms: Manager
# -----------------------------------------------------------------------------
# Marcio G.
# Jose Maria F.
# Daniel "Dan" C.
# Livia B.
#
# Descriptive Terms: Officer, Chief
# -------------------------------------------------------------------------------------------------------------------------------
# Andre M.
# Marcos R.
# Marcio Junior V.
# Eder B.
# Ricardo R.
# Frederico Q.
# Eduardo R.
# Lorena C.
# Romes P.
# José G.
# Edjay M.
# Joctã R.
# Thiago F.
# Thiago F.
#
# Descriptive Terms: Supervisora
# --------------------------------------------------
# Aline S.
# Thaís M.
#
# Descriptive Terms:
# -------------------------------------------------------------------------
# Humberto M.
# weberson alex s.
# Wannisson F.
#
# Descriptive Terms: Gerente
# -------------------------------------------------------
# Ricardo A.
# Lucas M.
#
# Descriptive Terms: Analista, de
# ---------------------------------------------------------------------------------------------------------------------------
# Willian B.
# Marcos Fernando B.
# Luis Gustavo d.
# Diogo Henrique G.
# Arthur D.
# Maycon E.
# Cristiano R.
#
# Descriptive Terms: TI
# -----------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Dinis, A.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Owner
# --------------------------------------
# Marcos R.
# B2B V.
# Assis M.
# Leonardo C.
# Aluisio Silva J.
# Pablo Henrique S.
# Terry  H.
#
# Descriptive Terms: Manager, Sales
# --------------------------------------------------------
# Marcio G.
# Marcos L.
#
# Descriptive Terms: Engenheiro, de, Software
# ------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Marcelo L.
# Renato B.
# Rodrigo G.
# Alan F.
# Guilherme C.
# Vinícius L.
# Rogério R.
# Welder N.
#
# Descriptive Terms: Analista, de
# -----------------------------------------------------------------------------------------------------
# Willian B.
# Marcos Fernando B.
# Luis Gustavo d.
# Diogo Henrique G.
# Arthur D.
# Cristiano R.
#
# Descriptive Terms: Officer, Chief
# ------------------------------------------------------------------------------------------------------
# Eduardo R.
# José G.
# Thiago F.
#
# Descriptive Terms: Especialista
# ----------------------------------------------------------------------------------
# Rodrigo O.
# Aniceto P.
# Roberto S.
# Rodrigo A.
#
# Descriptive Terms: Analista
# ---------------------------------------------------------------------------------------
# Thiago Willian A.
# Felipe P.
# Vagner A.
# Otávio F.
# Marcelo R.
#
# Descriptive Terms: Data
# --------------------------------------------
# Tiago M.
# Henrique C.
# Henrique C.
#
# Descriptive Terms:
# ---------------------------------------------------------------------------------------------------------------------------------------
# Robson X.
# Fabio C.
# Silvio Cesar M.
# Helio S.
# Uirá R.
# Uirá R.
# Randal C.
# Reiferson M.
# Carlos Á.
# Kleiber J.
# Pedro A.
# Rodrigo C.
# Denis L.
# Daiton J.
# Genivaldo O.
# Vicente N.
# Ricardo F.
# Luís Santos A.
# Hermes d.
# Pro D.
# Kleiber J.
#
# Descriptive Terms: Engenheiro, de, Software
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Renato B.
# Rodrigo G.
# Alan F.
# Guilherme C.
# Vinícius L.
# Rogério R.
# Welder N.
#
# Descriptive Terms: Informática
# -----------------------------------------------------
# Crenilson P.
# Crenilson P.
#
# Descriptive Terms:
# ---------------------------------------------------------------------
# Robson X.
# Daniel A.
# Flamaryon B.
# Silvio Cesar M.
# Felipe P.
# Sergio F.
#
# Descriptive Terms: r
# ------------------------------------------
# Luciano M.
# Luciano M.
# Antônio C.
# Rafael G.
# Árley L.
# Árley L.
# Eder B.
# Eder B.
# Eder B.
# Eder B.
# Vinícius C.
# Vinícius C.
# Fabiana P.
# Josenaldo d.
# Vazhakodan G.
# Marcos Paulo B.
# Jony T.
# Frederico A.
# Eduardo E.
# Luismar C.
# Wenceslau N.
# Filipe F.
# Filipe F.
# Thiago F.
# Thiago F.
# Thiago F.
# Thiago F.
# Lorena L.
# Erick O.
# Matheus G.
# Matheus G.
# Chrystian G.
#
# Descriptive Terms: Director
# ------------------------------------------------------
# Carlos Francisco F.
# Samuel B.
#
# Descriptive Terms: Gestor
# -------------------------------------------
# Ricardo T.
# Giselle M.
# Giselle M.
# Dieslei M.
#
# Descriptive Terms: Mercado
# ------------------------------------------
# Ricardo F.
# Dieslei M.
#
# Descriptive Terms: Diretor
# ------------------------------------------------------------------------------------------------------------------------------
# Robson X.
# Fabio C.
# Silvio Cesar M.
# Helio S.
# Reiferson M.
# Carlos Á.
# Kleiber J.
# Rodrigo C.
# Denis L.
# Daiton J.
# Genivaldo O.
# Vicente N.
# Ricardo F.
# Luís Santos A.
# Hermes d.
# Consultor e Auditor F.
# Pro D.
# Kleiber J.
#
# Descriptive Terms: TI
# ----------------------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Marcio M.
# Marcio M.
# Diego V.
# Luiz Alberto A.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Engenheiro, de, Software
# --------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# Renato B.
# Rodrigo G.
# Alan F.
# Vinícius L.
# Rogério R.
# Welder N.
#
# Descriptive Terms: Gestão, Consultor, em
# --------------------------------------------------------------------------------------------------
# Marcio M.
# Consultor e Auditor F.
#
# Descriptive Terms: Big, Data
# ---------------------------------------------------------
# José Antonio R.
# Henrique C.
# Henrique C.
#
# Descriptive Terms: Especialista
# --------------------------------------------------------
# Rodrigo O.
# Aniceto P.
# Roberto S.
#
# Descriptive Terms: Manager
# ---------------------------------------------------------------------------------------
# Flamaryon B.
# Jose Maria F.
# Livia B.
# Helder R.
#
# Descriptive Terms: Product
# ------------------------------------------------
# Aluisio Silva J.
# Livia B.
#
# Descriptive Terms: Officer, Chief
# -----------------------------------------------------------------
# Eduardo R.
# José G.
#
# Descriptive Terms: Manager
# ------------------------------------------------------------
# Marcio G.
# Jose Maria F.
# Livia B.
#
# Descriptive Terms: Consultant
# ------------------------------------------------------
# Yuri N.
# Osvaldo J.
#
# Descriptive Terms: Co
# --------------------------------
# Luciano M.
# José Henrique B.
# Eder B.
# Marcelo S.
# Vinícius C.
# Pablo Henrique S.
# Filipe F.
# Thiago F.
# Matheus G.
#
# Descriptive Terms: Processos
# -------------------------------------------------
# Ana Maria S.
# Fabiano D.
# Sérgio A.
# Mayra S.
# Túlio Kennedy O.
#
# Descriptive Terms: r
# ---------------------------------------
# Jony T.
# Wenceslau N.
#
# Descriptive Terms: IT, Manager
# --------------------------------------------------
# Flamaryon B.
# Jose Maria F.
#
# Descriptive Terms: Consultor
# -------------------------------------------------------------
# Andreia M.
# Leandro S.
# Bruno R.
# Jobenil Luiz M.
# Arthur M.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Flammarion C.
#
# Descriptive Terms: suporte
# ----------------------------------------
# Daniel O.
# Wendell C.
# Elvis R.
# Alirio P.
#
# Descriptive Terms: pleno
# ----------------------------------------------------------------
# Cristiano M.
# Wendell C.
# Tatiane M.
#
# Descriptive Terms: BI
# ----------------------------------------------------
# Marcelo H.
# Thiago Willian A.
# Bruno R.
# Hebert A.
# Patrícia A.
# Henrique C.
# Rafael B.
# Bruna A.
# Bruna A.
#
# Descriptive Terms: Manager
# ---------------------------------------------
# Jose Maria F.
# Livia B.
#
# Descriptive Terms:
# -----------------------------------------------------------
# Wendell C.
# Isabela Cristine C.
# Tatiane M.
#
# Descriptive Terms:
# ------------------------------------------------------------------------------
# Flamaryon B.
# Felipe P.
# Vagner A.
# Sergio F.
# Otávio F.
# Marcelo R.
#
# Descriptive Terms: Diretor
# -----------------------------------------------------------
# Fabio C.
# Helio S.
# Reiferson M.
# Carlos Á.
# Kleiber J.
# Rodrigo C.
# Denis L.
# Daiton J.
# Genivaldo O.
# Vicente N.
# Ricardo F.
# Luís Santos A.
# Hermes d.
# Pro D.
# Kleiber J.
#
# Descriptive Terms: Analista, de, Sistemas
# -------------------------------------------------------------------
# Willian B.
# Marcos Fernando B.
# Luis Gustavo d.
# Diogo Henrique G.
# Cristiano R.
#
# Descriptive Terms: Lea
# -----------------------------------
# Árley L.
# Árley L.
# Josenaldo d.
#
# Descriptive Terms: Analista
# -----------------------------------------------------------
# Vagner A.
# Otávio F.
# Marcelo R.
#
# Descriptive Terms: Diretor
# --------------------------------------------------
# Daiton J.
# Genivaldo O.
#
# Descriptive Terms: Engenheiro, de, Software
# ----------------------------------------------------------------------------------------------------------------------------------------------------
# Renato B.
# Rodrigo G.
# Alan F.
# Vinícius L.
# Rogério R.
#
# Descriptive Terms: Engenheiro, de, Software
# ------------------------------------------------------------------------------------------------------------------------
# Rodrigo G.
# Alan F.
# Vinícius L.
# Rogério R.
#
# Descriptive Terms: of, Head
# -------------------------------------------------------
# Luciano M.
# Luciano M.
# Luciano M.
# Luciano M.
# Felipe A.
# Jota J.
#
# Descriptive Terms: TI
# --------------------------------
# Andreia M.
# Fabio C.
# Ricardo A.
# Fabiano C.
# Germano M.
# Wagner P.
# Guilherme V.
# Henrique Fernandes P.
# Sandro C.
# Jony T.
# Rodrigo A.
# Giselle M.
# Giselle M.
# Vitor Adolfo A.
# Lucas M.
# Eduardo C.
# Marcio M.
# Marcio M.
# Diego V.
# Denis L.
# Vanderson (Az) B.
# Isabela Cristine C.
# Renato S.
# José Otavio A.
# Thiago Campos M.
# Kleiber J.
# Alirio P.
#
# Descriptive Terms: Consultor
# -----------------------------------------
# Andreia M.
# Bruno R.
# Jobenil Luiz M.
# Arthur M.
# Vanderson (Az) B.
# Roberto F.
# clemente dalmo l.
# Flammarion C.
#
# Descriptive Terms: Engenheiro, de, Software, full
# -------------------------------------------------------------------------------------------
# Vinícius L.
# Rogério R.
#
# Descriptive Terms: e, Sócio
# ----------------------------------------------
# Marcelo S.
# Hermes d.

# %% [markdown]
# ### Linkedin - Visualizando o agrupamento dos meus contatos por cargo

# %%
import os
import sys
import json
import webbrowser


HTML_TEMPLATE = 'dojo-tree.html'

data = {"label": "name", "temp_items": {}, "items": []}

clustered_contacts = cluster_contacts_by_title(CSV_FILE)

for titles in clustered_contacts:
    descriptive_terms = set(titles[0].split())
    for title in titles:
        descriptive_terms.intersection_update(set(title.split()))
    descriptive_terms = ', '.join(descriptive_terms)

    if descriptive_terms in data['temp_items']:
        data['temp_items'][descriptive_terms].extend([{'name': cc} for cc
                                                      in clustered_contacts[titles]])
    else:
        data['temp_items'][descriptive_terms] = [{'name': cc} for cc
                                                 in clustered_contacts[titles]]

for descriptive_terms in data['temp_items']:
    data['items'].append({"name": "%s (%s)" % (descriptive_terms,
                                               len(data['temp_items'][descriptive_terms]),),
                          "children": [i for i in
                                       data['temp_items'][descriptive_terms]]})

del data['temp_items']

# Open the template and substitute the data

if not os.path.isdir('out'):
    os.mkdir('out')

OUT = os.path.join('out', 'dojo-tree.html')

t = open(HTML_TEMPLATE).read()
f = open(OUT, 'w')
f.write(t % json.dumps(data, indent=4))
f.close()

webbrowser.open("file://" + os.path.join(os.getcwd(), OUT))
# Out:
# True
