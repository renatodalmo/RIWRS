# %%
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import json
import time

# %%
# setup security 
access_token = '28722914-E7p8sTCKIXo05khl6ORjCBsspCoPZkJhPGFhZKHK8'
access_token_secret = 'ynAkcIgBvKrZbLbDwmkxxJFmaPwmvBg3eZUAhVIQ'
consumer_key = '6i4ogA1u9hjUTkaMguUhQ'
consumer_secret = 'kv7pwUoYuBIG7xzvuyqs44XsS1KN8fG7SL5vnPKTqY'

# setup file store
file = 'tweets-sample-belgicaInglaterra.json'

# %%
class MyListener(StreamListener):
    def __init__(self, file):
        global the_file
        self.the_file = open(file, 'w')
        
    def on_data(self, data):
        self.the_file.write(data)
        
        tweet = json.loads(data)
        print(tweet['text'])
        
        return True
    
    def on_error(self, status):
        print(status)
        
    def file_close(self):
        self.the_file.close()

# %%
listener = MyListener(file)
oauth = OAuthHandler(consumer_key, consumer_secret)
oauth.set_access_token(access_token, access_token_secret)

max_time = 360 # in seconds
start_time = time.time() 

## collecting...
stream = Stream(oauth, listener)
#stream.filter(track=['copa', 'neymar', 'messi'],async=True,languages=['pt'])
stream.filter(track=['Belgium','England'],async=True)

elapsed_time = (time.time() - start_time)
while  elapsed_time < max_time:
    elapsed_time = (time.time() - start_time)

    
print('**Finish**')
stream.disconnect()
listener.file_close()
# Out:
# RT @snowmfb: Belgium vs England. The first 5 to predict the correct scoreline wins an instant recharge card.
# Follow on Twitter @snowmfb to…
# @Kwasi_rim @philclarke10 @ChristianMeah @LukeEdwardsTele @GuillemBalague @henrywinter That is disrespectful to the… https://t.co/cL8FCa50mY
# RT @FIFAWorldCup: RT if you're backing @England today!
#
# #BELENG // #WorldCup https://t.co/4lMS7jmsz2
# @thegoalzone @bhx_official @England @BHX_Police @andy4wm @_andywalker_ It all health and safety madness.  Would hav… https://t.co/za1G949eB3
# And still, rashford doesn’t start ahead of sterling https://t.co/PUxP6TTPdb
# IM NOT HAPPY!!!!! WHERES @JesseLingard @JHenderson ???!!!!!!!!!! @England please explain this 😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭😭… https://t.co/leYt4OLS7I
# @EL4JC: 'That moment when you forget where you left the Queen of England. #TrumpVisitsUK ' https://t.co/CXYubhEXYD,… https://t.co/ZzEcXLNDdx
# RT @FIFAWorldCup: RT if you're backing @England today!
#
# #BELENG // #WorldCup https://t.co/4lMS7jmsz2
# @TheJunosPizza Belgium 3 - 1 England
# RT @BCCI: 2nd ODI. 45.2: S Kaul to D Willey (19), 6 runs, 274/6 https://t.co/1m4bDdiRAe #EngvInd
# #royal #flashback July 14, 2017 - Katharine, HRH The Duchess of Kent, attends day eleven of the Wimbledon Tennis Ch… https://t.co/NXNchiyw5t
# @LucyBronze We are proud of u come on England 🏴󠁧󠁢󠁥󠁮󠁧󠁿🏴󠁧󠁢󠁥󠁮󠁧󠁿🏴󠁧󠁢󠁥󠁮󠁧󠁿🦁🦁🦁
# RT @julietrosejames: Free this weekend; 14/15th July; https://t.co/Ba9Xw5fNfS  A 17th century witch causes havoc when she lands in 21st cen…
# @SuperSportTV @NeilAndrews65 @TheAndreArendse @shaunbart9 Go Belgium, make us proud!
# @FIFAWorldCup @BelRedDevils @England Shit I thought that was Trippiers tournament when he got injured against Croatia..
# RT @England: The opportunity for our best @FIFAWorldCup finish since '66.
#
# 🆚 Belgium
# 🏆 #WorldCup third-place play-off
# ⏰ 3pm BST
# 🏟 Saint Pet…
# @GhQueen10 just save the tweet. As regards your question. They did what Chelsea couldn't. Champions League final an… https://t.co/W2XyFpWQaV
# Juve har gjort klart med Vidal https://t.co/bnz2VN5Ftv
# @CallumSecret @Laengar @cyrus_christie @GaryLineker Except they could be living in Uruguay but with English parents… https://t.co/3NEKwdcKtN
# RT @LIVEHDMATCH: @FIFAWorldCup @RomeluLukaku9 @HKane @adidasfootball Live Stream #WorldCup
# Belgium 🇧🇪Vs 🏴󠁧󠁢󠁥󠁮󠁧󠁿England
#
# Mobile 📱
# https://t.…
# @TecnoMobileInd BELGIUM will Win #BEL #WinWithTecno #BELvsENG #WorldCup
# Amaju Pinnick is match commissioner for England vs Belgium https://t.co/giZJWxjN5e https://t.co/NkRPRtfAop
# RT @BBCSport: Here's how England and Belgium line up for the #worldcup third place play-off.
#
# Live @5liveSport and right here
# 👉 https://t.c…
# RT @brianmoore666: 'Oi, get orf mi laand' - seriously, stunning photograph. https://t.co/FVNS0U176S
# aku dah terbayang roti telur bawang ni sambil menyaksikan england kecundang.
# She’s a clone https://t.co/D9S5rjkfP6
# @Wolves Serves you all right for watching a pre season game over England in a World Cup
# RT @BelRedDevils: Line-up ! ⚽
# 🆚 @England
#
# Last game ! Where do you watch ? 😊
#
# 📺 @rtbfsport / @sporza
#
# #REDTOGETHER
# #WorldCup
# #BELENG http…
# PES 2018 ENGLAND V BELGIUM 3RD PLACE PLAYOFF MATCH live at https://t.co/Fw9BwOZ9pK
# 888 #WorldCup
# Belgium 🇧🇪v England 🏴󠁧󠁢󠁥󠁮󠁧󠁿
# 11/1 England to win
# Use code 888ODDS
# New Customers
# T&amp;C's Apply,18+
# JOIN… https://t.co/VPd2tAQWnQ
# Kalau belgium menang an, sikit je la kita dapat...sorang singgit..kena pikir dua kali ni
# RT @momocricket: Unpopular Opinion: SA getting all out for 73 in Sri Lanka. Bangladesh getting all out for 43 in West Indies. England still…
# RT @England: Here's the #ThreeLions teamsheet for our last game of the 2018 #WorldCup.
#
# Keep doing us proud, lads! 💪 https://t.co/nVhxTbIE…
# RT @GracesSportsBar: We’ll be showing the World Cup third place play off today between Belgium v england.
#
# Straight after the game we’ll ha…
# @talkSPORT Belgium should have too much..
# No coma cuento...! El 3er lugar de la @FIFAWorldCup  paga 23 MD ! @BelRedDevils @England  #Rusia2018 https://t.co/7bvECuzOcD
# RT @England: Here's the #ThreeLions teamsheet for our last game of the 2018 #WorldCup.
#
# Keep doing us proud, lads! 💪 https://t.co/nVhxTbIE…
# RT @QualitySMC: @realDonaldTrump As usual, YOU have made us very proud @realDonaldTrump 💯
#
# #NATOSummit #England
#
# We trust &amp;  support you @P…
# @GaryLineker Amazing how many people have justified their belief in England’s arrogance by arrogantly belittling th… https://t.co/KPLzrbzj1n
# RT @England: Here's the #ThreeLions teamsheet for our last game of the 2018 #WorldCup.
#
# Keep doing us proud, lads! 💪 https://t.co/nVhxTbIE…
# RT @Jc_Le_Mulivha: Belgium or England?
# #BELENG
# RT @julietrosejames: Free this weekend; 14/15th July; https://t.co/Ba9Xw5fNfS  A 17th century witch causes havoc when she lands in 21st cen…
# England 0-1 Belgium – Full Post Match Discussion &amp; Reaction – World Cup #ENGBEL #ENG #BEL https://t.co/P9p5QC2hLU
# RT @FIFAWorldCup: RT if you're backing @England today!
#
# #BELENG // #WorldCup https://t.co/4lMS7jmsz2
# England once again lost their way in the middle overs. Otherwise it would have been 350 in the scoreboard after 50 overs. #ENGvIND
# RT @premierleague: #WorldCup goals
# @HKane - 6
# @RomeluLukaku9 - 4
#
# The two top scorers in Russia start the 3rd/4th play-off between Belgium…
# @TecnoMobileInd BELGIUM will Win #BEL #WinWithTecno #BELvsENG #WorldCup
# All the talk the season that past about how good dembele was for spurs and he can’t even get on that Belgium midfield!!! Overrated??
# #ThreeLions https://t.co/4wXViTgaSq
# @England He STILL won't drop Sterling. Fml.
# Good luck Belgium! Get the third place!
# RT @PFEW_Che: Dear #Police Officers in England and Wales, a quick request from me...
# If you tweet out something which requires the Federati…
# @TeamMelliIran England v Belgium preview: https://t.co/85AFITXvv5
# 2nd ODI. 45.4: S Kaul to D Willey (23), 4 runs, 278/6 https://t.co/1m4bDdiRAe #EngvInd
# ‘England and London’ we actually are a different country to the rest of those broke bums https://t.co/L6IvVsKMWQ
# RT @WhoScored: Confirmed XIs #BEL vs #ENG:
#
# Delph, Jones, Dier, Loftus-Cheek and Rose come into the starting XI for England
#
# Thomas Meunie…
# RT @BBCSport: Here's how England and Belgium line up for the #worldcup third place play-off.
#
# Live @5liveSport and right here
# 👉 https://t.c…
# Captain you misjudge the UK people. https://t.co/FLLdbVX8B9
# @themiddler69 @GuillemBalague I’ve not heard “it’s coming home” for a week - but everyone should be immensely proud… https://t.co/jM25LBV8cr
# RT @TheDoctorOfWho: Now I'm not overly versed in all the Royal Rules. But one surely any human knows is to not walk in front of the Queen..…
# // England is playing today, not gonna reply until the match finish 👀👀
# @naija927fm #sammyandthewisemen Belgium 1-0 England Chadli to score first
# Cmon Belgium! https://t.co/1xZtIiGIhP
# RT @__mitchbrown: #England #WorldCup⁠ ⁠ XI -
#
# Pickford
#
# Young
# Walker
# Stones
# Maguire
# Trippier
#
# Sterling
# Lingard
# Henderson
# Alli
#
# Kane
#
# But i…
# RT @Anarcho_Vampire: dr who: 'we're going to meet someone *very* important!'
#
# me: 'is it another time traveler? the ruler of some interdime…
# RT @Coral: The future is bright for England:
#
# 🏴󠁧󠁢󠁥󠁮󠁧󠁿 Under 17's - World Cup winners
# 🏴󠁧󠁢󠁥󠁮󠁧󠁿 Under 19's - Euro's winners
# 🏴󠁧󠁢󠁥󠁮󠁧󠁿 Under 20's…
# RT @oddminers: Haven't played this game yet,  need to load my account..  Looks good. @MisturBets ..i see Belgium beating England straight u…
# RT @IgokFC: If you’re going to be ridiculous then it was last year when the u17s won it https://t.co/4zZ8Zm36XH
# RT @Richard_Schiff: England!  Scotland! thank you.  We stand with you! We are Anglofiles and Scotofiles! https://t.co/4vVWQEABqA
# RT @WATCHMATCHTV: @FIFAWorldCup Live Stream #WorldCup
# Belgium 🇧🇪Vs 🏴󠁧󠁢󠁥󠁮󠁧󠁿England
#
# Mobile 📱
# https://t.co/rSXj7ZHfpm
# https://t.co/aWeLFwDNwI…
# RT @OmegaMan58: The Queen of England served Sarah Sanders, the Red Hen would not.
# Let that sink in. https://t.co/MgwAeKW66E
# Today Fifa World Cup matches are:
# Belgium - England 16:00 (GMT+2)
# Cheer on your team with Supporters app on Android… https://t.co/LoBnEddJcP
# RT @Footy_Headlines: 🏴󠁧󠁢󠁥󠁮󠁧󠁿🇧🇪 | 🇭🇷🇫🇷 Croatia &amp; France to Use Home Kits in 2018 World Cup Final + Surprising Belgium vs England Kit News: h…
# None of the other spouses even come close to our beautiful, elegant @FLOTUS !! 🌟🇺🇸💕 https://t.co/H8sDSVCrTd
# RT @Cj_covblaze: Our seventh (7 in one tournament, who’d of thought it?!) and final game in Russia. Flag is right behind the goal. Let’s fi…
# I feel bad for England already. losing twice in a week to a team they've lost to already. Nothing stamps the "we're… https://t.co/saRJbxnDg2
# RT @utdxtra: Really hope Romelu Lukaku smashes in a hat-trick to take the Golden Boot off Harry Kane. He’s had such a terrific World Cup. D…
# RT @barrystanton61: england performences ranked:
# Rose: 0
# Walker: 0
# Kane: 10
# Dier: 10
# Sterlin: -1
# Delf: 0
# Maguire: 10
# Rashferd: 0
# Stones:…
# RT @WhoScored: Confirmed XIs #BEL vs #ENG:
#
# Delph, Jones, Dier, Loftus-Cheek and Rose come into the starting XI for England
#
# Thomas Meunie…
# RT @FOXSports: The Golden Boot race likely comes down to this 3rd-place match between England and Belgium. 👀 https://t.co/oQ5bbTnf74
# RT @BBCSport: Here's how England and Belgium line up for the #worldcup third place play-off.
#
# Live @5liveSport and right here
# 👉 https://t.c…
# @Angry_Brexiter @seanair_iain @GaryLineker Good to chat. Going to watch tennis &amp; then see how England do 😉
# RT @OmegaMan58: The Queen of England served Sarah Sanders, the Red Hen would not.
# Let that sink in. https://t.co/MgwAeKW66E
# Exception in thread Thread-6:
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\http\client.py", line 588, in _readinto_chunked
#     n = self._safe_readinto(temp_mvb)
#   File "C:\Anaconda3\lib\http\client.py", line 630, in _safe_readinto
#     raise IncompleteRead(bytes(mvb[0:total_bytes]), len(b))
# http.client.IncompleteRead: IncompleteRead(0 bytes read, 4048 more expected)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\site-packages\urllib3\response.py", line 302, in _error_catcher
#     yield
#   File "C:\Anaconda3\lib\site-packages\urllib3\response.py", line 384, in read
#     data = self._fp.read(amt)
#   File "C:\Anaconda3\lib\http\client.py", line 449, in read
#     n = self.readinto(b)
#   File "C:\Anaconda3\lib\http\client.py", line 483, in readinto
#     return self._readinto_chunked(b)
#   File "C:\Anaconda3\lib\http\client.py", line 594, in _readinto_chunked
#     raise IncompleteRead(bytes(b[0:total_bytes]))
# http.client.IncompleteRead: IncompleteRead(8602 bytes read)
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "C:\Anaconda3\lib\threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "C:\Anaconda3\lib\threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\Anaconda3\lib\site-packages\tweepy\streaming.py", line 297, in _run
#     six.reraise(*exc_info)
#   File "C:\Anaconda3\lib\site-packages\six.py", line 693, in reraise
#     raise value
#   File "C:\Anaconda3\lib\site-packages\tweepy\streaming.py", line 266, in _run
#     self._read_loop(resp)
#   File "C:\Anaconda3\lib\site-packages\tweepy\streaming.py", line 325, in _read_loop
#     next_status_obj = buf.read_len(length)
#   File "C:\Anaconda3\lib\site-packages\tweepy\streaming.py", line 164, in read_len
#     self._buffer += self._stream.read(read_len)
#   File "C:\Anaconda3\lib\site-packages\urllib3\response.py", line 401, in read
#     raise IncompleteRead(self._fp_bytes_read, self.length_remaining)
#   File "C:\Anaconda3\lib\contextlib.py", line 99, in __exit__
#     self.gen.throw(type, value, traceback)
#   File "C:\Anaconda3\lib\site-packages\urllib3\response.py", line 320, in _error_catcher
#     raise ProtocolError('Connection broken: %r' % e, e)
# urllib3.exceptions.ProtocolError: ('Connection broken: IncompleteRead(8602 bytes read)', IncompleteRead(8602 bytes read))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-efe88605d2d5> in <module>()
#      13 elapsed_time = (time.time() - start_time)
#      14 while  elapsed_time < max_time:
# ---> 15     elapsed_time = (time.time() - start_time)
#      16
#      17
#
# KeyboardInterrupt:

# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
tweets_data = []
tweets_file = open(file, "r")
for line in tweets_file:
    try:
        tweet = json.loads(line)
        tweets_data.append(tweet)
    except:
        continue

# %%
tweets = pd.DataFrame()

tweets['lang'] = ''
tweets['text'] = ''
tweets['country'] = ''
for tweet in tweets_data:
    if 'lang' in tweet:
        tweets.loc[len(tweets)] = [tweet['lang'],
                               tweet['text'],
                               tweet['place']['country'] if tweet['place'] != None else None]
    
print(tweets.head(10))
# Out:
#   lang                                               text  country
# 0   en  RT @snowmfb: Belgium vs England. The first 5 t...     None
# 1   en  @Kwasi_rim @philclarke10 @ChristianMeah @LukeE...     None
# 2   en  RT @FIFAWorldCup: RT if you're backing @Englan...     None
# 3   en  @thegoalzone @bhx_official @England @BHX_Polic...     None
# 4   en  And still, rashford doesn’t start ahead of ste...  Nigeria
# 5   en  IM NOT HAPPY!!!!! WHERES @JesseLingard @JHende...     None
# 6   en  @EL4JC: 'That moment when you forget where you...     None
# 7   en  RT @FIFAWorldCup: RT if you're backing @Englan...     None
# 8   no               @TheJunosPizza Belgium 3 - 1 England     None
# 9   et  RT @BCCI: 2nd ODI. 45.2: S Kaul to D Willey (1...     None

# %%
tweets_by_lang = tweets['lang'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Languages', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 languages', fontsize=15, fontweight='bold')
tweets_by_lang[:5].plot(ax=ax, kind='bar', color='red')

# %%
tweets_by_country = tweets['country'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Countries', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 countries', fontsize=15, fontweight='bold')
tweets_by_country[:5].plot(ax=ax, kind='bar', color='blue')

# %%
import re
def word_in_text(word, text):
    word = word.lower()
    text = text.lower()
    match = re.search(word, text)
    if match:
        return True
    return False

# %%
## filtrando aqueles q mais foram falados (termos mais influentes)
players = []
for tweet in tweets_data:
    if 'text' in tweet:
        if word_in_text('Belgium', tweet['text']):
            players.append('Belgium')
        elif word_in_text('England', tweet['text']):
            players.append('England')
        else:
            players.append('None')
tweets['player'] = players
tweets.head(20)

# %%
tweets_by_player = tweets['player'].value_counts()

fig, ax = plt.subplots()
ax.tick_params(axis='x', labelsize=15)
ax.tick_params(axis='y', labelsize=10)
ax.set_xlabel('Players', fontsize=15)
ax.set_ylabel('Number of tweets' , fontsize=15)
ax.set_title('Top 5 players', fontsize=15, fontweight='bold')
tweets_by_player[:6].plot(ax=ax, kind='bar', color='green')

# %%
## Desafio: filtrando pelas coordenadas geográficas os tweets em português
